# %%
try:
    file = open('data.csv','x')
    file.close()
except:
    pass

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df
# Out:
#    sn    name  age        add       phone
# 0   1   Sabin   34  Kathmandu  9808667654
# 1   2   Nabin   23  Bhaktapur  9809778765
# 2   3   Akash   45   Lalitpur  9878778765
# 3   4     Ram   56       Bara  9808667654
# 4   5  Sabina   54    Chitwan  9867667654
# 5   6  Sarita   67  Kathmandu  9878778765

# %%
df.head()
# Out:
#    sn    name  age        add       phone
# 0   1   Sabin   34  Kathmandu  9808667654
# 1   2   Nabin   23  Bhaktapur  9809778765
# 2   3   Akash   45   Lalitpur  9878778765
# 3   4     Ram   56       Bara  9808667654
# 4   5  Sabina   54    Chitwan  9867667654

# %%
df.tail()
# Out:
#       name  age        add       phone
# sn
# 2    Nabin   23  Bhaktapur  9809778765
# 3    Akash   45   Lalitpur  9878778765
# 4      Ram   56       Bara  9808667654
# 5   Sabina   54    Chitwan  9867667654
# 6   Sarita   67  Kathmandu  9878778765

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'sn')
df
# Out:
#       name  age        add       phone
# sn
# 1    Sabin   34  Kathmandu  9808667654
# 2    Nabin   23  Bhaktapur  9809778765
# 3    Akash   45   Lalitpur  9878778765
# 4      Ram   56       Bara  9808667654
# 5   Sabina   54    Chitwan  9867667654
# 6   Sarita   67  Kathmandu  9878778765

# %%
import pandas as pd
cols = ['name','sn','phone']
df = pd.read_csv('data.csv',index_col = 'sn',usecols = cols)
df
# Out:
#       name       phone
# sn
# 1    Sabin  9808667654
# 2    Nabin  9809778765
# 3    Akash  9878778765
# 4      Ram  9808667654
# 5   Sabina  9867667654
# 6   Sarita  9878778765

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'sn')
df.iloc[1:4]
# Out:
#      name  age        add       phone
# sn
# 2   Nabin   23  Bhaktapur  9809778765
# 3   Akash   45   Lalitpur  9878778765
# 4     Ram   56       Bara  9808667654

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'name')
my_data = df.loc["Sabin":"Ram"]
my_data.to_csv('new_data.csv')
my_data
# Out:
#        sn  age        add       phone
# name
# Sabin   1   34  Kathmandu  9808667654
# Nabin   2   23  Bhaktapur  9809778765
# Akash   3   45   Lalitpur  9878778765
# Ram     4   56       Bara  9808667654

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'sn')
# list(df['add'])
df[df['add'] == 'Kathmandu']
# Out:
#       name  age        add       phone
# sn
# 1    Sabin   34  Kathmandu  9808667654
# 6   Sarita   67  Kathmandu  9878778765

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'sn')
# list(df['add'])
df[df['age'] > 40]
# Out:
#       name  age        add       phone
# sn
# 3    Akash   45   Lalitpur  9878778765
# 4      Ram   56       Bara  9808667654
# 5   Sabina   54    Chitwan  9867667654
# 6   Sarita   67  Kathmandu  9878778765

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'sn')
# list(df['add'])
df[(df['age'] > 40) & (df['add'] == 'Kathmandu')]
# Out:
#       name  age        add       phone
# sn
# 6   Sarita   67  Kathmandu  9878778765

# %%
import pandas as pd
data = {'Names':['Ram', 'Shyam', 'Hari','Bikash', 'Samrat'],
        'Address':['Kathmandu','Palpa','Pyuthan','Bhaktapur','Patan'],
        'Age':[21, 22, 20, 19, 18]}

df = pd.DataFrame(data)
df.to_csv('boooks.csv')
df
# Out:
#     Names    Address  Age
# 0     Ram  Kathmandu   21
# 1   Shyam      Palpa   22
# 2    Hari    Pyuthan   20
# 3  Bikash  Bhaktapur   19
# 4  Samrat      Patan   18

# %%
import csv
data = []
with open('data.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        data.append(dict(row))
data
# Out:
# [{'sn': '1',
#   'name': 'Sabin',
#   'age': '34',
#   'add': 'Kathmandu',
#   'phone': '9808667654'},
#  {'sn': '2',
#   'name': 'Nabin',
#   'age': '23',
#   'add': 'Bhaktapur',
#   'phone': '9809778765'},
#  {'sn': '3',
#   'name': 'Akash',
#   'age': '45',
#   'add': 'Lalitpur',
#   'phone': '9878778765'},
#  {'sn': '4', 'name': 'Ram', 'age': '56', 'add': 'Bara', 'phone': '9808667654'},
#  {'sn': '5',
#   'name': 'Sabina',
#   'age': '54',
#   'add': 'Chitwan',
#   'phone': '9867667654'},
#  {'sn': '6',
#   'name': 'Sarita',
#   'age': '67',
#   'add': 'Kathmandu',
#   'phone': '9878778765'}]
